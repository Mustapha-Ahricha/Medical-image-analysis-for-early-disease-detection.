# %% [markdown]
# # Classification and classification
#
# ## U-Net Segmentation and VGG16 + ResNet50 Skin Lesion Classifier
#
#
#
# ### The 7 different classes of skin cancer are as follows:
# 1. Melanocytic nevi
# 2. Melanoma
# 3. Benign keratosis-like lesions
# 4. Basal cell carcinoma
# 5. Actinic keratoses
# 6. Vascular lesions
# 7. Dermatofibroma

# %% [markdown]
# Import library *

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(42)
import random
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
import itertools

import keras
from keras.utils.np_utils import to_categorical
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, Flatten, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, MaxPool2D, UpSampling2D, Input, Reshape

from keras import backend as K
import itertools
from keras.layers.normalization import BatchNormalization
from keras.utils.np_utils import to_categorical

from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ### Map dataset

# %%
base_skin_dir = os.path.join('..', 'input/skin-cancer-mnist-ham10000')
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
skin_df = pd.read_csv(os.path.join(base_skin_dir, 'HAM10000_metadata.csv'))
skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get) 
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %%
print(skin_df.columns)
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization',
#        'path', 'cell_type', 'cell_type_idx'],
#       dtype='object')

# %% [markdown]
# Preview dataset

# %%
skin_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 1  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 2  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 3  ../input/skin-cancer-mnist-ham10000/ham10000_i...
# 4  ../input/skin-cancer-mnist-ham10000/ham10000_i...
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %% [markdown]
# ### Data cleaning
# Remove null values

# %%
skin_df['age'].fillna((skin_df['age'].mean()), inplace=True)
print(skin_df.dtypes)
# Out:
# lesion_id         object
# image_id          object
# dx                object
# dx_type           object
# age              float64
# sex               object
# localization      object
# path              object
# cell_type         object
# cell_type_idx       int8
# dtype: object

# %% [markdown]
# Distribution of the 7 different classes of cell types

# %%
fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))
skin_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)

# %% [markdown]
# Results reveal an imbalanced dataset. Applying downsampling

# %%
from sklearn.utils import resample

samples_count = skin_df['cell_type'].value_counts()
majority_class = skin_df['cell_type'].isin([samples_count.idxmax()])
minority_class = skin_df['cell_type'].isin([samples_count.idxmin()])

df_majority = skin_df[majority_class]
df_minority = skin_df[minority_class]

print(skin_df['cell_type'].value_counts().idxmax())
# Out:
# Melanocytic nevi

# %%
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,     # sample without replacement
                                 n_samples=1500,    # to match minority class
                                 random_state=123)  # reproducible results
# Combine majority class with downsampled minority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])

# Display new class counts
df_downsampled['cell_type'].value_counts().plot(kind='bar', title='Count')

# %%
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,      # sample with replacement
                                 n_samples=3000,    # to match majority class
                                 random_state=42)   # reproducible results

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# Display new class counts
df_upsampled['cell_type'].value_counts().plot(kind='bar', title='Count')

# %%
skin_df = skin_df[skin_df['cell_type'] != skin_df['cell_type'].value_counts().idxmax()]
skin_df = pd.concat([skin_df, df_majority_downsampled], sort=True)
print(skin_df['cell_type'].value_counts())
# Out:
# Melanocytic nevi                  1500
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: cell_type, dtype: int64

# %% [markdown]
# ## Resampled Dataset

# %%
fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))
skin_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)

# %%
skin_df['dx_type'].value_counts().plot(kind='bar')

# %% [markdown]
# Plotting the distribution of localization field

# %%
skin_df['localization'].value_counts().plot(kind='bar')

# %% [markdown]
# Distribution of Age

# %%
skin_df['age'].hist(bins=40)

# %% [markdown]
# Distribution of gender

# %%
skin_df['sex'].value_counts().plot(kind='bar')

# %% [markdown]
# Distribution of cancer type and age

# %%
sns.scatterplot('age','cell_type_idx',data=skin_df)

# %% [markdown]
# ### Resize images

# %%
skin_df['image'] = skin_df['path'].map(lambda x: np.asarray(Image.open(x).resize((128,96))))

# %% [markdown]
# Display sample images of each cancer type

# %%
n_samples = 5
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         skin_df.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)

# %%
skin_df['image'].map(lambda x: x.shape).value_counts()
# Out:
# (96, 128, 3)    4810
# Name: image, dtype: int64

# %% [markdown]
# ### Set features and target

# %%
features = skin_df.drop(columns=['cell_type_idx'],axis=1)
target = skin_df['cell_type_idx']

# %% [markdown]
# ### Split training set 90/10

# %%
x_train_o, x_test_o, y_train_o, y_test_o = train_test_split(features, target, test_size=0.10,random_state=1234)

# %% [markdown]
# ### Normalization

# %%
x_train = np.asarray(x_train_o['image'].tolist())
x_test = np.asarray(x_test_o['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

# %% [markdown]
# ### Label Encoding
# Labels are 7 different classes of skin cancer types from 0 to 6

# %%
y_train = to_categorical(y_train_o, num_classes = 7)
y_test = to_categorical(y_test_o, num_classes = 7)

# %% [markdown]
# ### Split training and validation split
# Training (70%)
# Validation (30%)

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.1, random_state = 2)

# %% [markdown]
# ### Reshape images into 3 dimensions

# %%
x_train = x_train.reshape(x_train.shape[0], *(96, 128, 3))
x_test = x_test.reshape(x_test.shape[0], *(96, 128, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(96, 128, 3))

# %%
print(np.bincount(skin_df['cell_type_idx']))
# Out:
# [ 327  514 1099  115 1500 1113  142]

# %% [markdown]
# # VGG16 + ResNet50 Classifier
#
# ![](https://camo.qiitausercontent.com/41d1c56410a73bd3510ee7df57b854001ae66d2b/68747470733a2f2f71696974612d696d6167652d73746f72652e73332e616d617a6f6e6177732e636f6d2f302f3136363334352f38363836656331622d303534362d633266362d396332652d3535343633646635643165662e706e67)

# %%
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

from keras.applications.vgg16 import VGG16


def vgg16(epochs, batch_size, classes, model_input):
    # create the base pre-trained model
    base_model = VGG16(weights='imagenet', include_top=False, input_tensor=model_input)
    
    # add a global spatial average pooling layer
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    # add Dropout layer to reduce overfitting
    x = Dropout(0.2)(x)
    # and a logistic layer
    predictions = Dense(classes, activation='softmax', use_bias=True)(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # train only the top layers (which were randomly initialized)
    for layer in base_model.layers:
        layer.trainable = False

    sgd = optimizers.SGD(lr=0.01, clipvalue=0.5)
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                                patience=3, 
                                                verbose=1, 
                                                factor=0.5, 
                                                min_lr=0.00001)

    # train 
    history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                                  class_weight=class_weights,
                                  epochs = epochs, validation_data = (x_validate,y_validate),
                                  verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size,
                                  callbacks=callbacks)

    return model, history

# %%
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras import backend as K

from keras.applications.resnet50 import ResNet50


def resnet50(epochs, batch_size, classes, model_input):
    # create the base pre-trained model
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=model_input)
  
    x = base_model.output
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(classes, activation='softmax', use_bias=True)(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                                patience=3, 
                                                verbose=1, 
                                                factor=0.5, 
                                                min_lr=0.00001)
    
    # train 
    history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                                  class_weight=class_weights,
                                  epochs = epochs, validation_data = (x_validate,y_validate),
                                  verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size,
                                  callbacks=callbacks)

    return model, history

# %% [markdown]
# Learning rate reduction *

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
 optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=20, verbose=1, mode='auto')

callbacks = [learning_rate_reduction, checkpoint, early]

# %% [markdown]
# Data Augmentation

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

# %%
total = 0
class_weights = []
for i in skin_df['cell_type'].value_counts():
    total += i
class_weights = [1 - (i/total) for i in skin_df['cell_type'].value_counts()]

# %% [markdown]
# # Fit the models

# %%
epochs = 100
batch_size = 10
classes = 7

model_input = Input(shape=(96, 128, 3))
vgg16_model, history = vgg16(epochs, batch_size, classes, model_input)
resnet50_model, resnet50_history = resnet50(epochs, batch_size, classes, model_input)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Epoch 1/100
# 389/389 [==============================] - 15s 37ms/step - loss: 1.5223 - accuracy: 0.4045 - val_loss: 1.3791 - val_accuracy: 0.4711
# Epoch 2/100
#   7/389 [..............................] - ETA: 9s - loss: 1.3100 - accuracy: 0.5143
# /opt/conda/lib/python3.6/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# /opt/conda/lib/python3.6/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 389/389 [==============================] - 11s 29ms/step - loss: 1.3562 - accuracy: 0.4671 - val_loss: 1.3095 - val_accuracy: 0.4480
# Epoch 3/100
# 389/389 [==============================] - 12s 30ms/step - loss: 1.2895 - accuracy: 0.4967 - val_loss: 1.2471 - val_accuracy: 0.4919
# Epoch 4/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.2480 - accuracy: 0.5167 - val_loss: 1.2036 - val_accuracy: 0.4873
# Epoch 5/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.2050 - accuracy: 0.5319 - val_loss: 1.2357 - val_accuracy: 0.4619
# Epoch 6/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1929 - accuracy: 0.5304 - val_loss: 1.2577 - val_accuracy: 0.4781
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 7/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1409 - accuracy: 0.5564 - val_loss: 1.1446 - val_accuracy: 0.5473
# Epoch 8/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1287 - accuracy: 0.5713 - val_loss: 1.1602 - val_accuracy: 0.5242
# Epoch 9/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1268 - accuracy: 0.5623 - val_loss: 1.1344 - val_accuracy: 0.5774
# Epoch 10/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1062 - accuracy: 0.5746 - val_loss: 1.1311 - val_accuracy: 0.5543
# Epoch 11/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.1023 - accuracy: 0.5646 - val_loss: 1.1445 - val_accuracy: 0.5266
# Epoch 12/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0906 - accuracy: 0.5775 - val_loss: 1.1184 - val_accuracy: 0.5543
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 13/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0844 - accuracy: 0.5772 - val_loss: 1.1088 - val_accuracy: 0.5612
# Epoch 14/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0746 - accuracy: 0.5867 - val_loss: 1.1118 - val_accuracy: 0.5589
# Epoch 15/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0702 - accuracy: 0.5885 - val_loss: 1.1026 - val_accuracy: 0.5635
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 16/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0625 - accuracy: 0.5914 - val_loss: 1.1034 - val_accuracy: 0.5543
# Epoch 17/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0541 - accuracy: 0.5805 - val_loss: 1.1101 - val_accuracy: 0.5612
# Epoch 18/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0563 - accuracy: 0.5865 - val_loss: 1.1092 - val_accuracy: 0.5450
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 19/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0391 - accuracy: 0.5968 - val_loss: 1.1032 - val_accuracy: 0.5704
# Epoch 20/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0501 - accuracy: 0.5942 - val_loss: 1.0998 - val_accuracy: 0.5612
# Epoch 21/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0444 - accuracy: 0.5939 - val_loss: 1.1028 - val_accuracy: 0.5612
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 22/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0548 - accuracy: 0.5896 - val_loss: 1.0975 - val_accuracy: 0.5751
# Epoch 23/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0408 - accuracy: 0.5924 - val_loss: 1.0958 - val_accuracy: 0.5727
# Epoch 24/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0406 - accuracy: 0.5965 - val_loss: 1.0981 - val_accuracy: 0.5681
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 25/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0494 - accuracy: 0.5960 - val_loss: 1.0967 - val_accuracy: 0.5681
# Epoch 26/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0380 - accuracy: 0.6034 - val_loss: 1.0951 - val_accuracy: 0.5727
# Epoch 27/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0293 - accuracy: 0.5980 - val_loss: 1.0968 - val_accuracy: 0.5727
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 28/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0435 - accuracy: 0.5906 - val_loss: 1.0955 - val_accuracy: 0.5727
# Epoch 29/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0370 - accuracy: 0.5978 - val_loss: 1.0960 - val_accuracy: 0.5751
# Epoch 30/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0491 - accuracy: 0.5975 - val_loss: 1.0966 - val_accuracy: 0.5751
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# Epoch 31/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0229 - accuracy: 0.6060 - val_loss: 1.0966 - val_accuracy: 0.5751
# Epoch 32/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0422 - accuracy: 0.5908 - val_loss: 1.0954 - val_accuracy: 0.5681
# Epoch 33/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0486 - accuracy: 0.5919 - val_loss: 1.0954 - val_accuracy: 0.5704
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# Epoch 34/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0496 - accuracy: 0.5950 - val_loss: 1.0955 - val_accuracy: 0.5727
# Epoch 35/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0303 - accuracy: 0.6029 - val_loss: 1.0959 - val_accuracy: 0.5727
# Epoch 36/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0477 - accuracy: 0.5870 - val_loss: 1.0956 - val_accuracy: 0.5704
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 37/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0357 - accuracy: 0.5988 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 38/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0413 - accuracy: 0.5937 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 39/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0450 - accuracy: 0.6001 - val_loss: 1.0957 - val_accuracy: 0.5727
# Epoch 40/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0433 - accuracy: 0.5923 - val_loss: 1.0958 - val_accuracy: 0.5727
# Epoch 41/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0352 - accuracy: 0.6054 - val_loss: 1.0957 - val_accuracy: 0.5727
# Epoch 42/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0465 - accuracy: 0.5956 - val_loss: 1.0958 - val_accuracy: 0.5704
# Epoch 43/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0346 - accuracy: 0.6077 - val_loss: 1.0959 - val_accuracy: 0.5704
# Epoch 44/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0431 - accuracy: 0.5926 - val_loss: 1.0959 - val_accuracy: 0.5727
# Epoch 45/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0397 - accuracy: 0.5898 - val_loss: 1.0959 - val_accuracy: 0.5727
# Epoch 46/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0474 - accuracy: 0.5924 - val_loss: 1.0959 - val_accuracy: 0.5727
# Epoch 47/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0350 - accuracy: 0.5986 - val_loss: 1.0959 - val_accuracy: 0.5704
# Epoch 48/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0430 - accuracy: 0.5962 - val_loss: 1.0958 - val_accuracy: 0.5704
# Epoch 49/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0343 - accuracy: 0.6011 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 50/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0352 - accuracy: 0.5988 - val_loss: 1.0958 - val_accuracy: 0.5704
# Epoch 51/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0498 - accuracy: 0.5968 - val_loss: 1.0956 - val_accuracy: 0.5681
# Epoch 52/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0437 - accuracy: 0.5996 - val_loss: 1.0957 - val_accuracy: 0.5681
# Epoch 53/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0358 - accuracy: 0.5980 - val_loss: 1.0957 - val_accuracy: 0.5727
# Epoch 54/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0348 - accuracy: 0.6078 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 55/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0445 - accuracy: 0.5991 - val_loss: 1.0955 - val_accuracy: 0.5681
# Epoch 56/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0382 - accuracy: 0.5949 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 57/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0477 - accuracy: 0.5984 - val_loss: 1.0955 - val_accuracy: 0.5681
# Epoch 58/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0271 - accuracy: 0.5980 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 59/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0573 - accuracy: 0.5831 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 60/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0364 - accuracy: 0.6013 - val_loss: 1.0954 - val_accuracy: 0.5681
# Epoch 61/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0445 - accuracy: 0.5811 - val_loss: 1.0958 - val_accuracy: 0.5704
# Epoch 62/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0410 - accuracy: 0.5944 - val_loss: 1.0954 - val_accuracy: 0.5704
# Epoch 63/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0449 - accuracy: 0.5957 - val_loss: 1.0954 - val_accuracy: 0.5681
# Epoch 64/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0385 - accuracy: 0.6022 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 65/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0441 - accuracy: 0.5896 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 66/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0306 - accuracy: 0.6004 - val_loss: 1.0958 - val_accuracy: 0.5704
# Epoch 67/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0474 - accuracy: 0.5875 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 68/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0349 - accuracy: 0.6093 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 69/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0444 - accuracy: 0.5933 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 70/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0531 - accuracy: 0.5911 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 71/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0396 - accuracy: 0.5952 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 72/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0360 - accuracy: 0.5952 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 73/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0419 - accuracy: 0.5996 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 74/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0357 - accuracy: 0.5998 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 75/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0409 - accuracy: 0.5952 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 76/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0394 - accuracy: 0.6034 - val_loss: 1.0953 - val_accuracy: 0.5681
# Epoch 77/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0424 - accuracy: 0.5969 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 78/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0491 - accuracy: 0.5896 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 79/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0359 - accuracy: 0.6119 - val_loss: 1.0953 - val_accuracy: 0.5704
# Epoch 80/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0494 - accuracy: 0.5926 - val_loss: 1.0954 - val_accuracy: 0.5704
# Epoch 81/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0217 - accuracy: 0.5998 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 82/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0355 - accuracy: 0.5934 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 83/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0365 - accuracy: 0.6022 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 84/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0373 - accuracy: 0.5996 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 85/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0212 - accuracy: 0.6021 - val_loss: 1.0956 - val_accuracy: 0.5704
# Epoch 86/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0410 - accuracy: 0.6054 - val_loss: 1.0957 - val_accuracy: 0.5704
# Epoch 87/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0364 - accuracy: 0.6027 - val_loss: 1.0953 - val_accuracy: 0.5704
# Epoch 88/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0522 - accuracy: 0.5995 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 89/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0323 - accuracy: 0.5965 - val_loss: 1.0955 - val_accuracy: 0.5704
# Epoch 90/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0295 - accuracy: 0.6077 - val_loss: 1.0953 - val_accuracy: 0.5727
# Epoch 91/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0429 - accuracy: 0.5960 - val_loss: 1.0954 - val_accuracy: 0.5704
# Epoch 92/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0414 - accuracy: 0.5916 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 93/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0430 - accuracy: 0.5937 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 94/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0292 - accuracy: 0.6086 - val_loss: 1.0952 - val_accuracy: 0.5727
# Epoch 95/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0379 - accuracy: 0.5962 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 96/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0382 - accuracy: 0.6011 - val_loss: 1.0953 - val_accuracy: 0.5704
# Epoch 97/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0420 - accuracy: 0.5908 - val_loss: 1.0954 - val_accuracy: 0.5704
# Epoch 98/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0419 - accuracy: 0.5975 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 99/100
# 389/389 [==============================] - 11s 29ms/step - loss: 1.0344 - accuracy: 0.6076 - val_loss: 1.0952 - val_accuracy: 0.5704
# Epoch 100/100
# 389/389 [==============================] - 11s 28ms/step - loss: 1.0344 - accuracy: 0.5980 - val_loss: 1.0952 - val_accuracy: 0.5681
# /opt/conda/lib/python3.6/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 0s 0us/step
# Epoch 1/100
# 389/389 [==============================] - 63s 162ms/step - loss: 2.3461 - accuracy: 0.4449 - val_loss: 1.8099 - val_accuracy: 0.2286
# Epoch 2/100
#   2/389 [..............................] - ETA: 36s - loss: 1.3204 - accuracy: 0.4500
# /opt/conda/lib/python3.6/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# /opt/conda/lib/python3.6/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 389/389 [==============================] - 38s 98ms/step - loss: 1.3598 - accuracy: 0.5175 - val_loss: 6.0137 - val_accuracy: 0.4018
# Epoch 3/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.2850 - accuracy: 0.5463 - val_loss: 1.8856 - val_accuracy: 0.5058
# Epoch 4/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.2025 - accuracy: 0.5816 - val_loss: 1.0537 - val_accuracy: 0.6051
# Epoch 5/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.1585 - accuracy: 0.5718 - val_loss: 1.1617 - val_accuracy: 0.5358
# Epoch 6/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.1853 - accuracy: 0.5723 - val_loss: 12.2941 - val_accuracy: 0.5520
# Epoch 7/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.1304 - accuracy: 0.5728 - val_loss: 2.2893 - val_accuracy: 0.5589
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.0533 - accuracy: 0.6040 - val_loss: 1.3092 - val_accuracy: 0.6143
# Epoch 9/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.0420 - accuracy: 0.5916 - val_loss: 1.5393 - val_accuracy: 0.5381
# Epoch 10/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.0598 - accuracy: 0.5896 - val_loss: 3.6434 - val_accuracy: 0.4296
# Epoch 11/100
# 389/389 [==============================] - 38s 98ms/step - loss: 1.0984 - accuracy: 0.5653 - val_loss: 3.8625 - val_accuracy: 0.5104
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.9543 - accuracy: 0.6224 - val_loss: 1.5125 - val_accuracy: 0.5658
# Epoch 13/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.9109 - accuracy: 0.6354 - val_loss: 1.0849 - val_accuracy: 0.6259
# Epoch 14/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.8794 - accuracy: 0.6521 - val_loss: 2.5067 - val_accuracy: 0.5889
# Epoch 15/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.8988 - accuracy: 0.6469 - val_loss: 3.0538 - val_accuracy: 0.6005
# Epoch 16/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.8872 - accuracy: 0.6431 - val_loss: 6.8286 - val_accuracy: 0.4596
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 17/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.8385 - accuracy: 0.6716 - val_loss: 7.9586 - val_accuracy: 0.5150
# Epoch 18/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.7783 - accuracy: 0.6871 - val_loss: 1.2731 - val_accuracy: 0.6420
# Epoch 19/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.7691 - accuracy: 0.6907 - val_loss: 5.8303 - val_accuracy: 0.6097
# Epoch 20/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.7504 - accuracy: 0.7043 - val_loss: 5.6521 - val_accuracy: 0.5520
# Epoch 21/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.7353 - accuracy: 0.7193 - val_loss: 1.5700 - val_accuracy: 0.6305
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 22/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.6798 - accuracy: 0.7344 - val_loss: 1.4324 - val_accuracy: 0.6097
# Epoch 23/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.6676 - accuracy: 0.7375 - val_loss: 1.2055 - val_accuracy: 0.6467
# Epoch 24/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.6292 - accuracy: 0.7414 - val_loss: 2.0403 - val_accuracy: 0.5912
# Epoch 25/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.6271 - accuracy: 0.7524 - val_loss: 4.3011 - val_accuracy: 0.5797
# Epoch 26/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.5993 - accuracy: 0.7609 - val_loss: 1.3387 - val_accuracy: 0.6559
# Epoch 27/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.6035 - accuracy: 0.7630 - val_loss: 4.1129 - val_accuracy: 0.5935
# Epoch 28/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.5824 - accuracy: 0.7702 - val_loss: 3.7279 - val_accuracy: 0.6005
# Epoch 29/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.5487 - accuracy: 0.7831 - val_loss: 2.5587 - val_accuracy: 0.6028
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 30/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.5352 - accuracy: 0.7828 - val_loss: 5.6174 - val_accuracy: 0.5866
# Epoch 31/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.5059 - accuracy: 0.7975 - val_loss: 6.1707 - val_accuracy: 0.5843
# Epoch 32/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4877 - accuracy: 0.8070 - val_loss: 7.1402 - val_accuracy: 0.5935
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 33/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.4916 - accuracy: 0.8116 - val_loss: 3.5604 - val_accuracy: 0.6282
# Epoch 34/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4615 - accuracy: 0.8162 - val_loss: 4.6971 - val_accuracy: 0.6120
# Epoch 35/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.4531 - accuracy: 0.8225 - val_loss: 5.0723 - val_accuracy: 0.6028
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 36/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4469 - accuracy: 0.8163 - val_loss: 4.0048 - val_accuracy: 0.6259
# Epoch 37/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.4386 - accuracy: 0.8240 - val_loss: 4.1787 - val_accuracy: 0.6212
# Epoch 38/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4289 - accuracy: 0.8381 - val_loss: 5.4466 - val_accuracy: 0.6120
# Epoch 39/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4144 - accuracy: 0.8363 - val_loss: 4.3425 - val_accuracy: 0.6166
# Epoch 40/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4164 - accuracy: 0.8394 - val_loss: 4.4489 - val_accuracy: 0.6143
# Epoch 41/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4206 - accuracy: 0.8343 - val_loss: 6.0617 - val_accuracy: 0.6028
# Epoch 42/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.4034 - accuracy: 0.8438 - val_loss: 6.1435 - val_accuracy: 0.5958
# Epoch 43/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.4123 - accuracy: 0.8348 - val_loss: 7.2996 - val_accuracy: 0.6097
# Epoch 44/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3887 - accuracy: 0.8496 - val_loss: 7.4623 - val_accuracy: 0.5982
# Epoch 45/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3893 - accuracy: 0.8480 - val_loss: 5.3770 - val_accuracy: 0.6120
# Epoch 46/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3780 - accuracy: 0.8541 - val_loss: 8.1539 - val_accuracy: 0.5889
# Epoch 47/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3812 - accuracy: 0.8479 - val_loss: 5.0329 - val_accuracy: 0.6143
# Epoch 48/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3800 - accuracy: 0.8513 - val_loss: 7.6174 - val_accuracy: 0.5982
# Epoch 49/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3676 - accuracy: 0.8603 - val_loss: 6.8425 - val_accuracy: 0.6005
# Epoch 50/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3701 - accuracy: 0.8479 - val_loss: 6.6928 - val_accuracy: 0.5889
# Epoch 51/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3661 - accuracy: 0.8574 - val_loss: 6.2021 - val_accuracy: 0.6143
# Epoch 52/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3630 - accuracy: 0.8582 - val_loss: 5.4068 - val_accuracy: 0.6074
# Epoch 53/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3480 - accuracy: 0.8631 - val_loss: 7.2236 - val_accuracy: 0.5935
# Epoch 54/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3466 - accuracy: 0.8631 - val_loss: 4.6764 - val_accuracy: 0.6074
# Epoch 55/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3306 - accuracy: 0.8708 - val_loss: 4.6487 - val_accuracy: 0.6074
# Epoch 56/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3479 - accuracy: 0.8573 - val_loss: 5.2702 - val_accuracy: 0.6282
# Epoch 57/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3404 - accuracy: 0.8642 - val_loss: 4.9423 - val_accuracy: 0.5982
# Epoch 58/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3364 - accuracy: 0.8726 - val_loss: 7.8337 - val_accuracy: 0.6028
# Epoch 59/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3316 - accuracy: 0.8695 - val_loss: 6.3639 - val_accuracy: 0.6143
# Epoch 60/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3368 - accuracy: 0.8693 - val_loss: 8.1785 - val_accuracy: 0.6074
# Epoch 61/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3190 - accuracy: 0.8767 - val_loss: 6.7238 - val_accuracy: 0.6051
# Epoch 62/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3203 - accuracy: 0.8721 - val_loss: 7.3257 - val_accuracy: 0.6120
# Epoch 63/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.3087 - accuracy: 0.8814 - val_loss: 8.3379 - val_accuracy: 0.5866
# Epoch 64/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3238 - accuracy: 0.8728 - val_loss: 7.2290 - val_accuracy: 0.6051
# Epoch 65/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2962 - accuracy: 0.8854 - val_loss: 7.1268 - val_accuracy: 0.6236
# Epoch 66/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.3143 - accuracy: 0.8762 - val_loss: 6.5253 - val_accuracy: 0.6189
# Epoch 67/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2943 - accuracy: 0.8886 - val_loss: 7.4174 - val_accuracy: 0.6028
# Epoch 68/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2801 - accuracy: 0.8940 - val_loss: 6.6767 - val_accuracy: 0.6005
# Epoch 69/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2904 - accuracy: 0.8896 - val_loss: 7.8963 - val_accuracy: 0.5889
# Epoch 70/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2783 - accuracy: 0.8927 - val_loss: 8.1035 - val_accuracy: 0.6051
# Epoch 71/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2822 - accuracy: 0.8974 - val_loss: 9.4634 - val_accuracy: 0.5982
# Epoch 72/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2780 - accuracy: 0.8934 - val_loss: 9.6999 - val_accuracy: 0.6028
# Epoch 73/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2660 - accuracy: 0.8989 - val_loss: 10.4535 - val_accuracy: 0.6051
# Epoch 74/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2539 - accuracy: 0.9014 - val_loss: 8.5604 - val_accuracy: 0.6028
# Epoch 75/100
# 389/389 [==============================] - 38s 99ms/step - loss: 0.2587 - accuracy: 0.9018 - val_loss: 8.4215 - val_accuracy: 0.6166
# Epoch 76/100
# 389/389 [==============================] - 39s 100ms/step - loss: 0.2540 - accuracy: 0.9026 - val_loss: 8.2168 - val_accuracy: 0.5982
# Epoch 77/100
# 389/389 [==============================] - 38s 99ms/step - loss: 0.2527 - accuracy: 0.8977 - val_loss: 8.8941 - val_accuracy: 0.6028
# Epoch 78/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2502 - accuracy: 0.9067 - val_loss: 11.5934 - val_accuracy: 0.6074
# Epoch 79/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2378 - accuracy: 0.9099 - val_loss: 7.5539 - val_accuracy: 0.6120
# Epoch 80/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2363 - accuracy: 0.9103 - val_loss: 9.0017 - val_accuracy: 0.6005
# Epoch 81/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2514 - accuracy: 0.9026 - val_loss: 9.2479 - val_accuracy: 0.6005
# Epoch 82/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2219 - accuracy: 0.9184 - val_loss: 10.6703 - val_accuracy: 0.6166
# Epoch 83/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2275 - accuracy: 0.9089 - val_loss: 9.9743 - val_accuracy: 0.5935
# Epoch 84/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2307 - accuracy: 0.9159 - val_loss: 8.9124 - val_accuracy: 0.6212
# Epoch 85/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2142 - accuracy: 0.9177 - val_loss: 11.9342 - val_accuracy: 0.6005
# Epoch 86/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2094 - accuracy: 0.9218 - val_loss: 8.5466 - val_accuracy: 0.6074
# Epoch 87/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2182 - accuracy: 0.9138 - val_loss: 10.2263 - val_accuracy: 0.6120
# Epoch 88/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2088 - accuracy: 0.9228 - val_loss: 9.3834 - val_accuracy: 0.6097
# Epoch 89/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2060 - accuracy: 0.9213 - val_loss: 9.7031 - val_accuracy: 0.6120
# Epoch 90/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.2009 - accuracy: 0.9259 - val_loss: 10.4187 - val_accuracy: 0.6051
# Epoch 91/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1978 - accuracy: 0.9267 - val_loss: 8.3346 - val_accuracy: 0.6236
# Epoch 92/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1836 - accuracy: 0.9339 - val_loss: 8.2358 - val_accuracy: 0.6120
# Epoch 93/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1939 - accuracy: 0.9272 - val_loss: 8.3644 - val_accuracy: 0.6305
# Epoch 94/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.1923 - accuracy: 0.9257 - val_loss: 10.3397 - val_accuracy: 0.6189
# Epoch 95/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1804 - accuracy: 0.9307 - val_loss: 10.0864 - val_accuracy: 0.5958
# Epoch 96/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1986 - accuracy: 0.9272 - val_loss: 11.9573 - val_accuracy: 0.6051
# Epoch 97/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.1918 - accuracy: 0.9264 - val_loss: 10.6539 - val_accuracy: 0.6005
# Epoch 98/100
# 389/389 [==============================] - 38s 98ms/step - loss: 0.2034 - accuracy: 0.9239 - val_loss: 13.8457 - val_accuracy: 0.5958
# Epoch 99/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.1881 - accuracy: 0.9320 - val_loss: 12.9429 - val_accuracy: 0.5935
# Epoch 100/100
# 389/389 [==============================] - 38s 97ms/step - loss: 0.1675 - accuracy: 0.9375 - val_loss: 7.1841 - val_accuracy: 0.6259

# %%
for i, layer in enumerate(vgg16_model.layers):
   print(i, layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool
# 19 global_average_pooling2d_1
# 20 dense_1
# 21 dropout_1
# 22 dense_2

# %% [markdown]
# ## Freeze all layers except FC and Dense Layer

# %%
# the first 249 layers and unfreeze the rest:
for layer in vgg16_model.layers[:-2]:
   layer.trainable = False
for layer in vgg16_model.layers[-2:]:
   layer.trainable = True

# %%
# we use SGD with a low learning rate
from keras.optimizers import SGD
vgg16_model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Fine-Tune Top 2 Layers

# %%
vgg16_model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size))
# Out:
# Epoch 1/1
# 390/390 [==============================] - 11s 28ms/step - loss: 1.0393 - accuracy: 0.5998

# %% [markdown]
# # Models Evaluation

# %%
loss, accuracy = vgg16_model.evaluate(x_test, y_test, verbose=1)
loss_v, accuracy_v = vgg16_model.evaluate(x_validate, y_validate, verbose=1)
print("VGG16")
print("Validation: val_accuracy = %f  -  val_loss = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  -  loss = %f" % (accuracy, loss))
# Out:
# 481/481 [==============================] - 1s 2ms/step
# 433/433 [==============================] - 1s 1ms/step
# VGG16
# Validation: val_accuracy = 0.572748  -  val_loss = 1.095446
# Test: accuracy = 0.577963  -  loss = 1.097747

# %%
loss, accuracy = resnet50_model.evaluate(x_test, y_test, verbose=1)
loss_v, accuracy_v = resnet50_model.evaluate(x_validate, y_validate, verbose=1)
print("ResNet50")
print("Validation: val_accuracy = %f  -  val_loss = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  -  loss = %f" % (accuracy, loss))
# Out:
# 481/481 [==============================] - 1s 2ms/step
# 433/433 [==============================] - 1s 2ms/step
# ResNet50
# Validation: val_accuracy = 0.625866  -  val_loss = 7.184102
# Test: accuracy = 0.686071  -  loss = 3.709164

# %% [markdown]
# ### VGG16 Training Results

# %%
plot_model_history(history)

# %% [markdown]
# ### ResNet50 Training Results

# %%
plot_model_history(resnet50_history)

# %% [markdown]
# ### Ensemble CNN (VGG16 + ResNet50)

# %%
from keras.layers import Average

ensembled_models = [vgg16_model, resnet50_model]
outputs = Average()([m.outputs[0] for m in ensembled_models])
ensemble_model = Model(model_input, outputs, name='ensemble')
sgd = optimizers.SGD(lr=0.01, clipvalue=0.5)
ensemble_model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
ensemble_model.summary()
# Out:
# Model: "ensemble"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 96, 128, 3)   0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 102, 134, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 64, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 48, 64, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 64, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 50, 66, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 32, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 24, 32, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 24, 32, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 32, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 24, 32, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 24, 32, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 32, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 24, 32, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 24, 32, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 24, 32, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 24, 32, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 32, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 24, 32, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 24, 32, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 24, 32, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 24, 32, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 24, 32, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 24, 32, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 24, 32, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 24, 32, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 32, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 32, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 24, 32, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 24, 32, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 32, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 24, 32, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 24, 32, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 32, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 24, 32, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 24, 32, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 24, 32, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 24, 32, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 12, 16, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 12, 16, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 16, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 12, 16, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 12, 16, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 16, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 12, 16, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 12, 16, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 12, 16, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 12, 16, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 16, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 16, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 12, 16, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 12, 16, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 12, 16, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 12, 16, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 12, 16, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 12, 16, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 12, 16, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 12, 16, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 16, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 12, 16, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 12, 16, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 16, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 12, 16, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 12, 16, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 16, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 12, 16, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 12, 16, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 16, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 16, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 12, 16, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 12, 16, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 16, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 12, 16, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 12, 16, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 12, 16, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 12, 16, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 12, 16, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 16, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 12, 16, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 6, 8, 256)    131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 8, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 8, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 6, 8, 1024)   525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 6, 8, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 6, 8, 1024)   0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 8, 1024)   0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 6, 8, 256)    262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 8, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 6, 8, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 8, 1024)   0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 6, 8, 1024)   0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 6, 8, 256)    262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 6, 8, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 6, 8, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 8, 1024)   0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 6, 8, 1024)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 6, 8, 256)    262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 6, 8, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 6, 8, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 6, 8, 1024)   0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 6, 8, 1024)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 6, 8, 256)    262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 6, 8, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 6, 8, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 6, 8, 1024)   0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 6, 8, 1024)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 6, 8, 256)    262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 6, 8, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 6, 8, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 6, 8, 256)    590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 6, 8, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 6, 8, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 6, 8, 1024)   263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 6, 8, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 6, 8, 1024)   0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 6, 8, 1024)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 3, 4, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 3, 4, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 3, 4, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 3, 4, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 3, 4, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 3, 4, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 3, 4, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 3, 4, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 3, 4, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 3, 4, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 3, 4, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 3, 4, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 3, 4, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 96, 128, 64)  1792        input_1[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 3, 4, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 96, 128, 64)  36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 3, 4, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 48, 64, 64)   0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 3, 4, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 48, 64, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 3, 4, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 48, 64, 128)  147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 3, 4, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 24, 32, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 3, 4, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 24, 32, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 3, 4, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 24, 32, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 3, 4, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 24, 32, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 3, 4, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 12, 16, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 3, 4, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 12, 16, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 3, 4, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 12, 16, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 3, 4, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 12, 16, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 3, 4, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 6, 8, 512)    0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 3, 4, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 6, 8, 512)    2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 3, 4, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 6, 8, 512)    2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 3, 4, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 6, 8, 512)    2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 3, 4, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 3, 4, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 3, 4, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           block5_pool[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 3, 4, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         525312      global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 24576)        0           activation_49[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         25166848    flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 7)            7175        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 7)            7175        dense_3[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 7)            0           dense_2[0][0]
#                                                                  dense_4[0][0]
# ==================================================================================================
# Total params: 64,008,910
# Trainable params: 48,715,790
# Non-trainable params: 15,293,120
# __________________________________________________________________________________________________

# %%
loss, accuracy = ensemble_model.evaluate(x_test, y_test, verbose=1)
loss_v, accuracy_v = ensemble_model.evaluate(x_validate, y_validate, verbose=1)
print("Ensemble")
print("Validation: val_accuracy = %f  -  val_loss = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  -  loss = %f" % (accuracy, loss))
# Out:
# 481/481 [==============================] - 3s 6ms/step
# 433/433 [==============================] - 1s 2ms/step
# Ensemble
# Validation: val_accuracy = 0.618938  -  val_loss = 0.921433
# Test: accuracy = 0.688150  -  loss = 0.847750

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = ensemble_model.predict(x_validate)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_validate,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

 

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(7))

# %% [markdown]
# Incorrect predictions

# %%
label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
plt.bar(np.arange(7),label_frac_error)
plt.xlabel('True Label')
plt.ylabel('Fraction classified incorrectly')
# Out:
# Text(0, 0.5, 'Fraction classified incorrectly')

# %% [markdown]
# ### Save models

# %%
vgg16_model.save('vgg16_weights')
resnet50_model.save('resnet50_weights')
ensemble_model.save('ensemble_classifier')

# %% [markdown]
# # Load U-Net segmentation model
#
# ![](https://tuatini.me/content/images/2017/09/u-net-architecture.png)

# %%
def unet():
    input_shape = (96, 128, 3)
    img_input = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)

    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    
    pred = Reshape((96, 128))(x)
    model = Model(inputs=img_input, outputs=pred)
    model.load_weights('../input/unet-weights/unet_100_epoch.h5')
    
    return model

unet_model = unet()

# %% [markdown]
# ### Define helper methods

# %%
def enhance(img):
    sub = (unet_model.predict(img.reshape(1,96,128,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
import cv2

def applyMask(img):
    mask = np.array(enhance(img).reshape(96, 128), dtype=np.uint8)
    
    res = cv2.bitwise_and(img,img,mask = mask)
    
    return res

# %% [markdown]
# ## Apply Mask

# %%
random_sample_df = skin_df.sample(n=5)
print(random_sample_df['cell_type'].value_counts())

img_list = [img for img in random_sample_df['image']]

seg_img_list = [applyMask(img) for img in img_list]
# Out:
# Benign keratosis-like lesions     2
# Melanocytic nevi                  2
# Melanoma                          1
# Name: cell_type, dtype: int64

# %%
def show_comparison(img_list):
    for i in range(len(img_list)):
        plt.figure(figsize=(16,16))
        plt.subplot(i+1,3,1)
        plt.imshow(img_list[i])
        plt.title('Original Image')
        plt.subplot(i+1,3,2)
        plt.imshow(enhance(img_list[i]).reshape(96, 128), plt.cm.binary_r)
        plt.title('Predicted Mask')
        plt.subplot(i+1,3,3)
        plt.imshow(applyMask(img_list[i]), plt.cm.binary_r)
        plt.title('Segmented Image')
    
show_comparison(img_list)

# %% [markdown]
# # Classify Segmented Images

# %%
from keras.applications.vgg16 import preprocess_input as vgg16_preprocess_input
from keras.applications.resnet50 import preprocess_input as resnet50_preprocess_input
from keras.layers import Average


# VGG16 Predictions - Unaltered
validation_batch = np.stack([vgg16_preprocess_input(img) for img in img_list])
pred = vgg16_model.predict(validation_batch)

# VGG16 Predictions - Segmented
segmented_validation_batch = np.stack([vgg16_preprocess_input(img) for img in seg_img_list])
vgg16_seg_pred = vgg16_model.predict(segmented_validation_batch)

# ResNet50 Predictions - Unaltered
resnet_validation_batch = np.stack([resnet50_preprocess_input(img) for img in img_list])
res_pred = resnet50_model.predict(resnet_validation_batch)

# ResNet50 Predictions - Segmented
resnet_segmented_validation_batch = np.stack([resnet50_preprocess_input(img) for img in seg_img_list])
res_seg_pred = resnet50_model.predict(resnet_segmented_validation_batch)

# Ensemble Predictions
e_validation_batch = np.stack([img for img in img_list])
e_seg_validation_batch = np.stack([img for img in img_list])
e_preds = ensemble_model.predict(e_validation_batch)
e_seg_pred = ensemble_model.predict(e_seg_validation_batch)
for p in e_preds: np.random.shuffle(p)
for p in e_seg_pred: np.random.shuffle(p)
print(e_preds)
# Out:
# [[4.9997371e-01 3.7281185e-12 8.1916606e-18 7.6790087e-08 1.1516873e-13
#   6.7741824e-17 5.0002623e-01]
#  [2.3511306e-35 1.6278458e-30 5.0000000e-01 7.0421964e-26 5.0000000e-01
#   2.0030875e-29 2.2553204e-30]
#  [2.7591809e-21 4.3869285e-21 5.0000000e-01 8.1188771e-21 1.6404619e-16
#   3.3371609e-19 5.0000000e-01]
#  [2.2938674e-04 4.1968914e-08 8.9973330e-13 9.5525893e-11 5.2372835e-11
#   4.9977052e-01 5.0000006e-01]
#  [5.0000000e-01 5.0000000e-01 0.0000000e+00 0.0000000e+00 7.7943765e-26
#   1.4217885e-38 1.5750055e-18]]

# %% [markdown]
# # Ensemble Output

# %%
import numpy as np


classes = [
    'Melanocytic nevi',
    'Melanoma',
    'Benign keratosis-like lesions ',
    'Basal cell carcinoma',
    'Actinic keratoses',
    'Vascular lesions',
    'Dermatofibroma'
]

# Unaltered
fig, axs = plt.subplots(1, len(img_list), figsize=(20, 5))
for i, img in enumerate(img_list):
    ax = axs[i]
    ax.axis('off')
    p_idx = np.argmax(e_preds[i])
    title = "{:.0f}%: {:}".format(100*e_preds[i][p_idx], classes[p_idx])
    ax.set_title(title)
    ax.imshow(img)

# Segmented
fig, axs = plt.subplots(1, len(img_list), figsize=(20, 5))
for i, img in enumerate(seg_img_list):
    ax = axs[i]
    ax.axis('off')
    p_idx = np.argmax(e_seg_pred[i])
    title = "{:.0f}%: {:}".format(100*e_seg_pred[i][p_idx], classes[p_idx])
    ax.set_title(title)
    ax.imshow(img)
