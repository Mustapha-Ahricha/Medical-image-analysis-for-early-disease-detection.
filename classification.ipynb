# %%
from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPool2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Model, load_model, save_model

from tensorflow.keras.callbacks import EarlyStopping ,CSVLogger
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
from math import ceil
import pandas as pd 
import cv2 as cv
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn as sk
import keras 
from tensorflow.keras import datasets, layers, models
# %matplotlib inline
# Out:
# WARNING:tensorflow:From c:\Users\zayna\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Functions

# %%
def load_data(dir_list, image_size):


    # load all images in a directory
    data = []
    label = []
    image_width, image_height = image_size
    
    for directory in dir_list:
        for filename in os.listdir(directory):
            
            image = cv.imread(directory + '/' + filename,0)

            image = cv.resize(image, dsize=(image_width, image_height), interpolation=cv.INTER_CUBIC)

            image = image / 255.0
            image= image.astype(np.float32)

            data.append(image)

            if directory == 'yes':
                label.append([1]) ## have tumor
                
            else:
                label.append([0]) ## donot have tumor 
            

    data_array = np.array(data)
    label = np.array(label) 
    return data_array, label

# %% [markdown]
# # loading data
# now time to loading data with pre procssing like resizing ...

# %%
x,y=load_data(['yes','no'],(256,256))
# print(x[2])
print(y[2])
plt.imshow(x[2], cmap='gray')
plt.axis('off')
plt.title('sample_image')
# Out:
# [1]
# Text(0.5, 1.0, 'sample_image')

# %% [markdown]
# # splitting data
# for training data we have to split our data
# - train dataset 0.8
# - validate dataset 0.2 (optional)
# - test dataset 0.2 <br />
# validation dataset in this case are equal

# %%
def split_data(test_size=0.2 , log=True):
    x_train, x_test_val, y_train, y_test_val = train_test_split(x, y, test_size=test_size,shuffle=True)
    if log==True : 
        print('Input Shape : ')
        print(x_train.shape,(y_train).shape)
        print(x_test_val.shape,(y_test_val).shape)
    x_test=x_test_val
    x_val=x_test_val
    y_test=y_test_val
    y_val=y_test_val
    
        
    x_train=x_train.reshape(-1,256,256,1)  
#     y_train=y_train.reshape(-1,100,100,1)  
#     y_test=y_test.reshape(-1,100,100,1)    
    x_test=x_test.reshape(-1,256,256,1)
    x_val=x_val.reshape(-1,256,256,1)
    if log==True : 
        print('Output Shape : ')
        print(x_train.shape,y_train.shape)
        print(x_test.shape,y_test.shape)
        print(x_val.shape,y_val.shape)
    return x_train, x_test, y_train, y_test,x_val,y_val
x_train, x_test, y_train, y_test,x_val,y_val=split_data()
validation_dataset=(x_val,y_val)
# Out:
# Input Shape :
# (2400, 256, 256) (2400, 1)
# (600, 256, 256) (600, 1)
# Output Shape :
# (2400, 256, 256, 1) (2400, 1)
# (600, 256, 256, 1) (600, 1)
# (600, 256, 256, 1) (600, 1)

# %% [markdown]
# # Build Model

# %%
def Build_Model(input_shape=(256,256,1)):
    Model = keras.models.Sequential([
            Conv2D(16,kernel_size=(3,3),activation='relu',input_shape=input_shape),
            Conv2D(32,kernel_size=(3,3),activation='relu'),
            MaxPool2D(2,2),
            Conv2D(32,kernel_size=(3,3),activation='relu'),    
            Conv2D(32,kernel_size=(3,3),activation='relu'),    
            Conv2D(64,kernel_size=(3,3),activation='relu'),
            MaxPool2D(4,4),
            Flatten() ,    
            Dense(64,activation='relu') ,        
            Dense(32,activation='relu') ,   
            Dense(16,activation='relu'),
            Dropout(rate=0.5) ,            
            Dense(1,activation='sigmoid') ,    
            ])
    return Model

# %%
Model=Build_Model()
Model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\zayna\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\zayna\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      160
#
#  conv2d_1 (Conv2D)           (None, 252, 252, 32)      4640
#
#  max_pooling2d (MaxPooling2  (None, 126, 126, 32)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 124, 124, 32)      9248
#
#  conv2d_3 (Conv2D)           (None, 122, 122, 32)      9248
#
#  conv2d_4 (Conv2D)           (None, 120, 120, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 64)                3686464
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3730881 (14.23 MB)
# Trainable params: 3730881 (14.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\zayna\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
def make_callbacks(csv_path='/kaggle/working/my_class_log_5.csv'):
    early_stop=EarlyStopping(monitor='val_loss',patience=8,mode='min',restore_best_weights=False)
    csv_logger=CSVLogger(csv_path)
    callbacks =[early_stop,csv_logger]
    return callbacks
callbacks=make_callbacks()

# %%
epochs = 32
Model.fit(x_train, y_train, epochs=epochs,batch_size=32,verbose=1,validation_data=validation_dataset)
# Out:
# Epoch 1/32
# 75/75 [==============================] - 60s 805ms/step - loss: 0.3625 - accuracy: 0.8221 - val_loss: 0.2281 - val_accuracy: 0.8983
# Epoch 2/32
# 75/75 [==============================] - 62s 825ms/step - loss: 0.2378 - accuracy: 0.9071 - val_loss: 0.1664 - val_accuracy: 0.9450
# Epoch 3/32
# 75/75 [==============================] - 59s 781ms/step - loss: 0.1524 - accuracy: 0.9488 - val_loss: 0.1536 - val_accuracy: 0.9517
# Epoch 4/32
# 75/75 [==============================] - 59s 781ms/step - loss: 0.0986 - accuracy: 0.9692 - val_loss: 0.1206 - val_accuracy: 0.9633
# Epoch 5/32
# 75/75 [==============================] - 61s 809ms/step - loss: 0.1334 - accuracy: 0.9604 - val_loss: 0.1432 - val_accuracy: 0.9483
# Epoch 6/32
# 75/75 [==============================] - 59s 790ms/step - loss: 0.1078 - accuracy: 0.9650 - val_loss: 0.1082 - val_accuracy: 0.9683
# Epoch 7/32
# 75/75 [==============================] - 58s 770ms/step - loss: 0.0686 - accuracy: 0.9779 - val_loss: 0.0885 - val_accuracy: 0.9850
# Epoch 8/32
# 75/75 [==============================] - 57s 755ms/step - loss: 0.0517 - accuracy: 0.9842 - val_loss: 0.0969 - val_accuracy: 0.9783
# Epoch 9/32
# 75/75 [==============================] - 56s 747ms/step - loss: 0.0355 - accuracy: 0.9896 - val_loss: 0.0955 - val_accuracy: 0.9767
# Epoch 10/32
# 75/75 [==============================] - 58s 779ms/step - loss: 0.0424 - accuracy: 0.9892 - val_loss: 0.0967 - val_accuracy: 0.9867
# Epoch 11/32
# 75/75 [==============================] - 60s 802ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.1160 - val_accuracy: 0.9883
# Epoch 12/32
# 75/75 [==============================] - 57s 765ms/step - loss: 0.0652 - accuracy: 0.9767 - val_loss: 0.1049 - val_accuracy: 0.9867
# Epoch 13/32
# 75/75 [==============================] - 59s 783ms/step - loss: 0.0260 - accuracy: 0.9933 - val_loss: 0.1630 - val_accuracy: 0.9733
# Epoch 14/32
# 75/75 [==============================] - 57s 760ms/step - loss: 0.0341 - accuracy: 0.9896 - val_loss: 0.1853 - val_accuracy: 0.9683
# Epoch 15/32
# 75/75 [==============================] - 57s 761ms/step - loss: 0.0345 - accuracy: 0.9867 - val_loss: 0.1490 - val_accuracy: 0.9683
# Epoch 16/32
# 75/75 [==============================] - 57s 760ms/step - loss: 0.0530 - accuracy: 0.9883 - val_loss: 0.1204 - val_accuracy: 0.9850
# Epoch 17/32
# 75/75 [==============================] - 57s 760ms/step - loss: 0.0297 - accuracy: 0.9917 - val_loss: 0.1022 - val_accuracy: 0.9850
# Epoch 18/32
# 75/75 [==============================] - 59s 789ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.1478 - val_accuracy: 0.9883
# Epoch 19/32
# 75/75 [==============================] - 58s 768ms/step - loss: 0.0177 - accuracy: 0.9904 - val_loss: 0.1493 - val_accuracy: 0.9900
# Epoch 20/32
# 75/75 [==============================] - 57s 763ms/step - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.1453 - val_accuracy: 0.9883
# Epoch 21/32
# 75/75 [==============================] - 58s 773ms/step - loss: 0.0149 - accuracy: 0.9967 - val_loss: 0.1611 - val_accuracy: 0.9850
# Epoch 22/32
# 75/75 [==============================] - 58s 767ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.1497 - val_accuracy: 0.9767
# Epoch 23/32
# 75/75 [==============================] - 138s 2s/step - loss: 0.0651 - accuracy: 0.9783 - val_loss: 0.0777 - val_accuracy: 0.9883
# Epoch 24/32
# 75/75 [==============================] - 62s 827ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.1120 - val_accuracy: 0.9900
# Epoch 25/32
# 75/75 [==============================] - 58s 776ms/step - loss: 0.0122 - accuracy: 0.9975 - val_loss: 0.1333 - val_accuracy: 0.9883
# Epoch 26/32
# 75/75 [==============================] - 58s 771ms/step - loss: 0.0121 - accuracy: 0.9983 - val_loss: 0.1451 - val_accuracy: 0.9883
# Epoch 27/32
# 75/75 [==============================] - 57s 760ms/step - loss: 0.0131 - accuracy: 0.9942 - val_loss: 0.1557 - val_accuracy: 0.9900
# Epoch 28/32
# 75/75 [==============================] - 57s 764ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.1624 - val_accuracy: 0.9900
# Epoch 29/32
# 75/75 [==============================] - 57s 767ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.1778 - val_accuracy: 0.9867
# Epoch 30/32
# 75/75 [==============================] - 57s 762ms/step - loss: 0.0111 - accuracy: 0.9983 - val_loss: 0.1894 - val_accuracy: 0.9883
# Epoch 31/32
# 75/75 [==============================] - 57s 766ms/step - loss: 0.0138 - accuracy: 0.9937 - val_loss: 0.1989 - val_accuracy: 0.9883
# Epoch 32/32
# 75/75 [==============================] - 57s 765ms/step - loss: 0.0153 - accuracy: 0.9937 - val_loss: 0.1887 - val_accuracy: 0.9883

# %% [markdown]
# # saving trained model

# %%
Model.save('tumor_classification_trained_model_by_parham_2.h5')
# Out:
# c:\Users\zayna\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
Model.save('C:/Users/zayna/Desktop/tumor_classification_trained_model_by_parham_2.h5')

# %% [markdown]
# # load training model

# %%
Model = load_model('tumor_classification_trained_model_by_parham_2.h5')

# %% [markdown]
# # evaluating

# %%
Model_loss, Model_accuracy = Model.evaluate(x_test, y_test)

print(f"it is Model accuracy: {Model_accuracy}")
print(f'it is Model loss: {Model_loss}')
# Out:
# 19/19 [==============================] - 4s 206ms/step - loss: 0.1887 - accuracy: 0.9883
# it is Model accuracy: 0.9883333444595337
# it is Model loss: 0.18872924149036407

# %% [markdown]
# # Visualizing output

# %%
def predict_human_readable(array):
    array=array.flatten()
#     print(array[0])
    result=1 if array>0.5 else 0
    return result   
#----------------------------------------
def predict_on_custome_image(img_path,img_or_directory=False,plot=False):
    dict_1={}
    if img_or_directory==False :
        array=cv.imread(img_path,0)
        
        shape_array=array.shape
        array_1=cv.resize(array,(256,256))
        
        y,x=array_1.shape
#         array_1=array_1 / 255.0
        array=array_1.reshape(1,y,x,1)
        #-------
#         print(array.shape)
        y_predict=Model.predict(array)
        y_predict_res=predict_human_readable(y_predict)
        

        if y_predict_res== 1:
            predicted='Tumor Detected'
            
        else : 
            predicted='do not have tumor'
        
        dict_1.update({img_path:predicted})
        if plot==True :
            plt.imshow(array_1,cmap='gray')
            plt.title(predicted)
            plt.axis('off')
    else :
        all_img=os.listdir(img_path)
        image_count=len(all_img)
#         print(all_img)
        if plot==True :
            rows,columns=3,ceil(image_count/3)
            fig = plt.figure(figsize=(20, 14))
            
        for c,path in enumerate(all_img) :
            lst_1=path.split('.')
            if lst_1[1]=='jpg' or lst_1[1]=='png' or lst_1[1]=='jpeg': 
                array=cv.imread(img_path+'/'+path,0)
    #             print(img_path+'/'+path)
                shape_array=array.shape
                array_1=cv.resize(array,(256,256))
                y,x=array_1.shape
#                 array_1=array_1 / 255.0
#                 array_1= array_1.astype(np.float32)
                array=array_1.reshape(1,y,x,1)
                
            #-------

                y_predict=Model.predict(array)
                y_predict_res=predict_human_readable(y_predict)
                if y_predict_res==1 :
                    predicted='Tumor Detected'

                else : 
                    predicted='do not have tumor'
                dict_1.update({path:predicted})
                if plot==True :
                    fig.add_subplot(rows, columns, c+1)
                    plt.imshow(array_1,cmap='gray')
                    plt.title(predicted)
                    plt.axis('off')
            else :
                continue
    return dict_1           
a=predict_on_custome_image('C:/Users/zayna/Desktop/Input/tumor',img_or_directory=True,plot=True)
print(a)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 44ms/step
# {'y175.jpg': 'Tumor Detected', 'y176.jpg': 'Tumor Detected', 'y177.jpg': 'Tumor Detected'}

# %% [markdown]
# # plot accuracy

# %%
csv=pd.read_csv('my_class_log_5.csv')
accuracy=csv['accuracy']
loss=csv['loss']
val_accuracy=csv['val_accuracy']
val_loss=csv['val_loss']
print(csv[['loss','val_loss','accuracy','val_accuracy']])
# Out:
#         loss  val_loss  accuracy  val_accuracy
# 0   0.577611  0.428239  0.712500      0.778333
# 1   0.397102  0.292536  0.830000      0.898333
# 2   0.205892  0.202001  0.920833      0.926667
# 3   0.164755  0.185451  0.938333      0.946667
# 4   0.103642  0.133125  0.962083      0.975000
# 5   0.088993  0.141238  0.967083      0.971667
# 6   0.071294  0.052753  0.976250      0.970000
# 7   0.032612  0.048283  0.987083      0.980000
# 8   0.032870  0.023204  0.986667      0.973333
# 9   0.028039  0.031217  0.988333      0.981667
# 10  0.012749  0.020890  0.993750      0.988333
# 11  0.009394  0.015284  0.995833      0.983333
# 12  0.024086  0.037236  0.989167      0.983333

# %%
plt.plot(accuracy,label='Training Accuracy')
plt.plot(val_accuracy,label='Validation Accuracy')
plt.legend()
plt.title('Classification Model Accuracy')
plt.show()

# %%
plt.plot(loss,label='Training Loss',)
plt.plot(val_loss,label='Validation Loss')

plt.legend()
plt.title('Classification Model Loss')
plt.show()
